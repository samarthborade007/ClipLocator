# %%
import numpy as np
from youtube_transcript_api import YouTubeTranscriptApi
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import spacy
from gensim.models import Word2Vec

# %%
def extract_transcript_with_timestamps(video_id):
    try:
        transcript_list = YouTubeTranscriptApi.get_transcript(video_id)
        transcript_with_timestamps = ''
        for segment in transcript_list:
            start_time = segment['start']
            end_time = segment['start'] + segment['duration']
            transcript_with_timestamps += f"[{format_time(start_time)} - {format_time(end_time)}] {segment['text']}\n"
        return transcript_with_timestamps, transcript_list
    except Exception as e:
        print("An error occurred:", e)
        return None, None

# %%
def format_time(seconds):
    minutes, seconds = divmod(seconds, 60)
    hours, minutes = divmod(minutes, 60)
    return '{:02}:{:02}:{:02}'.format(int(hours), int(minutes), int(seconds))

# %%
# Load English tokenizer, tagger, parser, NER, and word vectors
nlp = spacy.load("en_core_web_sm")

# %%
# # Load Word2Vec model
# word2vec_model = Word2Vec.load("GoogleNews-vectors-negative300.bin")

# %%
# Function to predict timestamps for a given subtopic
def predict_timestamps(transcript_list, subtopic):
    # Extract text from transcript segments
    segments_text = [segment['text'] for segment in transcript_list]

    # Perform named entity recognition (NER) on the subtopic
    doc = nlp(subtopic)
    ner_subtopic = [ent.text for ent in doc.ents]

    # Keyword extraction for the subtopic
    keywords = [token.text for token in doc if not token.is_stop]

    # Combine NER entities and keywords
    subtopic_tokens = set(ner_subtopic + keywords)

    # Vectorize the segments and the subtopic tokens
    vectorizer = TfidfVectorizer()
    X = vectorizer.fit_transform(segments_text)
    subtopic_vec = vectorizer.transform([" ".join(subtopic_tokens)])

    # Compute cosine similarity between subtopic and each segment
    similarities = cosine_similarity(X, subtopic_vec)

    # Get index of the segment with highest similarity
    closest_segment_index = np.argmax(similarities)

    # Get the start time of the closest segment
    closest_segment = transcript_list[closest_segment_index]
    start_time = closest_segment['start']
    return start_time

# %%
# Replace 'VIDEO_ID' with the actual ID of the YouTube video
video_id = 'PYS3UZFPJWI'
transcript_with_timestamps, transcript_list = extract_transcript_with_timestamps(video_id)

print("Transcript with Timestamps:")
print(transcript_with_timestamps)
# Out:
# Transcript with Timestamps:
# [00:00:05 - 00:00:11] hey guys it's kendall i am so excited to
# [00:00:09 - 00:00:13] be back for my second beauty secrets
# [00:00:11 - 00:00:15] video with vogue i did my last one
# [00:00:13 - 00:00:17] almost four years ago and i was just a
# [00:00:15 - 00:00:19] little baby and
# [00:00:17 - 00:00:21] my routine has completely changed since
# [00:00:19 - 00:00:24] then so i'm excited to show you guys my
# [00:00:21 - 00:00:26] new routine i obviously look really
# [00:00:24 - 00:00:29] really crazy i have this avocado mask on
# [00:00:26 - 00:00:30] that i make myself in my kitchen
# [00:00:29 - 00:00:32] and
# [00:00:30 - 00:00:35] um it's super fun to make and super easy
# [00:00:32 - 00:00:37] i put an avocado in a bowl and then mash
# [00:00:35 - 00:00:38] it up with some oatmeal
# [00:00:37 - 00:00:40] this
# [00:00:38 - 00:00:42] superfood honey
# [00:00:40 - 00:00:45] i got it from courtney so i'm assuming
# [00:00:42 - 00:00:48] it's really good and natural and then
# [00:00:45 - 00:00:50] this organic lavender oil i just drop a
# [00:00:48 - 00:00:52] drop or two into it and that's pretty
# [00:00:50 - 00:00:55] much it it's really easy feels really
# [00:00:52 - 00:00:57] nice and it moisturizes you makes you
# [00:00:55 - 00:00:59] glowy
# [00:00:57 - 00:01:00] and when i'm trying to give my skin a
# [00:00:59 - 00:01:04] little extra love
# [00:01:00 - 00:01:06] i have this amazing pure genix
# [00:01:04 - 00:01:08] collagen mask i love it so much and i
# [00:01:06 - 00:01:10] keep it in the refrigerator
# [00:01:08 - 00:01:13] right now i have it in this bowl of ice
# [00:01:10 - 00:01:16] along with my roller thingies that i'll
# [00:01:13 - 00:01:16] use in a sec
# [00:01:19 - 00:01:23] i'm really like to roll over
# [00:01:24 - 00:01:27] get in under your eyes especially like
# [00:01:26 - 00:01:29] if i have
# [00:01:27 - 00:01:32] really early work or a really early show
# [00:01:29 - 00:01:32] i throw this on
# [00:01:34 - 00:01:38] my skin definitely feels like it acts up
# [00:01:36 - 00:01:40] a bit more during fashion month
# [00:01:38 - 00:01:42] just because like so much is going on
# [00:01:40 - 00:01:43] they're like
# [00:01:42 - 00:01:46] putting so much makeup on you and using
# [00:01:43 - 00:01:48] a ton of product so i've gotten like
# [00:01:46 - 00:01:51] really gnarly rashes just from like
# [00:01:48 - 00:01:52] probably someone using the same brush on
# [00:01:51 - 00:01:54] me and another girl at the end of a
# [00:01:52 - 00:01:56] lineup and they're just rushing all this
# [00:01:54 - 00:01:59] powder on to you so
# [00:01:56 - 00:02:02] i'm really like
# [00:01:59 - 00:02:07] you know ocd now about my skin what i
# [00:02:02 - 00:02:07] let touch my face during fashion week
# [00:02:09 - 00:02:14] sometimes i'll take it like clump it
# [00:02:11 - 00:02:17] into a ball and rub the extra
# [00:02:14 - 00:02:21] let it sit for a sec
# [00:02:17 - 00:02:22] now i'm going to just rinse my face i
# [00:02:21 - 00:02:24] love
# [00:02:22 - 00:02:26] this cleanser it is by christy kidd it's
# [00:02:24 - 00:02:26] called clean
# [00:02:30 - 00:02:35] i have always been super into my skin
# [00:02:33 - 00:02:37] especially when i was about like 14 and
# [00:02:35 - 00:02:38] started breaking out i started like
# [00:02:37 - 00:02:41] really
# [00:02:38 - 00:02:42] you know getting into skin care and i
# [00:02:41 - 00:02:44] remember i would go to like the pharmacy
# [00:02:42 - 00:02:47] with my mom and get all these probably
# [00:02:44 - 00:02:49] not great products and i've just been
# [00:02:47 - 00:02:51] really into it for so long just because
# [00:02:49 - 00:02:54] i have had acne prone skin so
# [00:02:51 - 00:02:56] for me it's just like something that
# [00:02:54 - 00:02:58] was an obvious thing i felt i needed to
# [00:02:56 - 00:03:01] get into and seeing my own skin journey
# [00:02:58 - 00:03:02] has taught me so much
# [00:03:01 - 00:03:04] so yeah i've kind of come up with this
# [00:03:02 - 00:03:07] regimen and this routine that really
# [00:03:04 - 00:03:10] works for me it's been really really
# [00:03:07 - 00:03:13] okay since i mean i obviously am human i
# [00:03:10 - 00:03:14] have my breakouts here and there um
# [00:03:13 - 00:03:16] but
# [00:03:14 - 00:03:18] yeah it's been so much better than what
# [00:03:16 - 00:03:20] it was before but it was it was brutal
# [00:03:18 - 00:03:20] for a moment
# [00:03:20 - 00:03:24] i wear sunscreen every day use this elta
# [00:03:23 - 00:03:26] md clear
# [00:03:24 - 00:03:28] i just use a little bit and then i
# [00:03:26 - 00:03:32] sometimes mix it honestly most days i
# [00:03:28 - 00:03:35] mix it with this skinceuticals serum
# [00:03:32 - 00:03:35] four to five drops
# [00:03:36 - 00:03:42] mix it around
# [00:03:39 - 00:03:42] get it on there
# [00:03:43 - 00:03:49] i love i mean clearly i love it it's
# [00:03:45 - 00:03:53] like nearly gone this um mario badescu
# [00:03:49 - 00:03:53] green tea cucumber aloe spray
# [00:03:55 - 00:04:00] i love these um exfoliating makeup wipes
# [00:03:58 - 00:04:02] for my lips just before i put on makeup
# [00:04:00 - 00:04:04] so i like
# [00:04:02 - 00:04:06] scrub my lips to get all the dead skin
# [00:04:04 - 00:04:06] off
# [00:04:07 - 00:04:10] i was trying to figure out for so long
# [00:04:08 - 00:04:11] why my skin was breaking out was it
# [00:04:10 - 00:04:13] hormones was it what i'm eating am i
# [00:04:11 - 00:04:15] allergic to something am i using the
# [00:04:13 - 00:04:17] wrong products and once i felt like i
# [00:04:15 - 00:04:19] got my regimen down i knew that it
# [00:04:17 - 00:04:22] wasn't what i was putting on my face i
# [00:04:19 - 00:04:25] started thinking about my diet a lot and
# [00:04:22 - 00:04:28] decided to cut out dairy
# [00:04:25 - 00:04:30] not entirely i love cheese so it's hard
# [00:04:28 - 00:04:33] for me to cut out cheese and that
# [00:04:30 - 00:04:35] honestly helped me so much and i drink
# [00:04:33 - 00:04:38] tons of water as much as i can or
# [00:04:35 - 00:04:41] remember to so after i scrub with my
# [00:04:38 - 00:04:44] exfoliating makeup wipe i love this
# [00:04:41 - 00:04:46] kylie skin lip mask i put it on
# [00:04:44 - 00:04:47] while i'm doing my makeup and then once
# [00:04:46 - 00:04:50] i'm done
# [00:04:47 - 00:04:53] and ready to move on to like doing my
# [00:04:50 - 00:04:53] lipstick i wipe it off
# [00:04:53 - 00:05:00] my last step before i do my makeup is
# [00:04:56 - 00:05:00] this lemare cream
# [00:05:03 - 00:05:06] and now i am
# [00:05:04 - 00:05:08] ready to do my makeup
# [00:05:06 - 00:05:11] this is what i would do if i'm like
# [00:05:08 - 00:05:12] going out to dinner or um you know
# [00:05:11 - 00:05:14] doing something a little more than just
# [00:05:12 - 00:05:16] like running out the house really fast
# [00:05:14 - 00:05:19] but still pretty natural i'm like i love
# [00:05:16 - 00:05:22] a natural look it just works for me
# [00:05:19 - 00:05:26] um so yeah this is the foundation that i
# [00:05:22 - 00:05:26] use it's just chanel
# [00:05:28 - 00:05:32] i don't
# [00:05:29 - 00:05:34] love to feel like i have too much on i
# [00:05:32 - 00:05:34] think the lighter the better just some
# [00:05:34 - 00:05:36] good
# [00:05:34 - 00:05:38] light coverage
# [00:05:36 - 00:05:39] i was a huge tomboy when i was younger
# [00:05:38 - 00:05:41] so i
# [00:05:39 - 00:05:43] i didn't wear makeup like i'd say as
# [00:05:41 - 00:05:44] much as kylie did
# [00:05:43 - 00:05:45] but
# [00:05:44 - 00:05:48] i still
# [00:05:45 - 00:05:51] loved to play around with it and um
# [00:05:48 - 00:05:54] was honestly never that good and then as
# [00:05:51 - 00:05:56] i got older and like through my job and
# [00:05:54 - 00:05:58] through just like
# [00:05:56 - 00:06:00] seeing how people do my makeup you learn
# [00:05:58 - 00:06:02] so much about like what looks good on
# [00:06:00 - 00:06:04] you and what doesn't
# [00:06:02 - 00:06:06] so yeah when i'm done applying with this
# [00:06:04 - 00:06:10] really soft brush
# [00:06:06 - 00:06:10] i use my beauty blender
# [00:06:13 - 00:06:20] all these different colors
# [00:06:15 - 00:06:20] i usually go for this guy in this guy
# [00:06:28 - 00:06:32] you'll see all the differences between
# [00:06:30 - 00:06:35] like me and kylie kylie's like a legit
# [00:06:32 - 00:06:37] professional and i'm like you know what
# [00:06:35 - 00:06:37] this works
# [00:06:42 - 00:06:46] i literally can do my makeup in like 15
# [00:06:44 - 00:06:48] minutes or less
# [00:06:46 - 00:06:50] 20 tops
# [00:06:48 - 00:06:52] and so kylie and i are very different
# [00:06:50 - 00:06:54] because she is like
# [00:06:52 - 00:06:57] you know
# [00:06:54 - 00:06:58] full beat
# [00:06:57 - 00:07:00] but i respect it
# [00:06:58 - 00:07:03] she takes a lot longer but you know what
# [00:07:00 - 00:07:05] she looks fire so
# [00:07:03 - 00:07:08] i've seen i've seen like some magical
# [00:07:05 - 00:07:09] moments though where she
# [00:07:08 - 00:07:11] um
# [00:07:09 - 00:07:13] gets ready pretty quickly
# [00:07:11 - 00:07:15] and i love it
# [00:07:13 - 00:07:18] bronzer time so i usually start with
# [00:07:15 - 00:07:20] like a like a creamy bronzer and i love
# [00:07:18 - 00:07:22] obviously my
# [00:07:20 - 00:07:26] kindle by kylie cosmetics i just like to
# [00:07:22 - 00:07:26] be able to apply it like
# [00:07:26 - 00:07:30] like a marker
# [00:07:33 - 00:07:37] so i kind of just draw it on and then i
# [00:07:35 - 00:07:40] take this big
# [00:07:37 - 00:07:44] kind of stiff brush
# [00:07:40 - 00:07:44] blend it all in
# [00:07:44 - 00:07:48] [Music]
# [00:07:46 - 00:07:51] i probably have one too many steps when
# [00:07:48 - 00:07:51] it comes to bronzing
# [00:07:53 - 00:07:59] i'm like all about like a non-perfect
# [00:07:57 - 00:08:01] be like it just works
# [00:07:59 - 00:08:04] my biggest fear is like putting on
# [00:08:01 - 00:08:05] bronzer and having like lines on my face
# [00:08:04 - 00:08:10] because i didn't blend it enough or
# [00:08:05 - 00:08:10] a line down here so i love to make
# [00:08:11 - 00:08:16] in sure it's a blessing and a curse to
# [00:08:13 - 00:08:19] grow up in the spotlight because
# [00:08:16 - 00:08:21] it has not always been cute and i have
# [00:08:19 - 00:08:24] not always known
# [00:08:21 - 00:08:26] what to do or
# [00:08:24 - 00:08:30] what the right makeup move is so i've
# [00:08:26 - 00:08:30] definitely had some probably
# [00:08:30 - 00:08:35] not hot moments
# [00:08:32 - 00:08:37] okay and then sometimes this is a nice
# [00:08:35 - 00:08:39] double-sided
# [00:08:37 - 00:08:40] brush sometimes i'll take the small side
# [00:08:39 - 00:08:43] after i contour my nose a little bit and
# [00:08:40 - 00:08:43] i'll go
# [00:08:46 - 00:08:50] i'm gonna go in with my blush i love
# [00:08:48 - 00:08:52] creams first because like i said i love
# [00:08:50 - 00:08:56] like a dewy look so i just think using
# [00:08:52 - 00:08:56] like creams makes everything even dewier
# [00:08:57 - 00:09:00] no real rules here
# [00:09:02 - 00:09:06] and then i'm gonna go in with this
# [00:09:03 - 00:09:09] really dewy marc jacobs
# [00:09:06 - 00:09:13] creamy highlighter
# [00:09:09 - 00:09:13] i'm going with my finger
# [00:09:15 - 00:09:21] also i think if i could only live with
# [00:09:18 - 00:09:23] two makeup products it would be
# [00:09:21 - 00:09:25] highlighter and bronzer
# [00:09:23 - 00:09:26] i've just lived such an awesome life
# [00:09:25 - 00:09:29] when it comes to like
# [00:09:26 - 00:09:30] getting like the craziest makeup hair
# [00:09:29 - 00:09:32] and makeup looks like i've been
# [00:09:30 - 00:09:36] transformed into so many things i'd say
# [00:09:32 - 00:09:36] some of my favorite transformations
# [00:09:36 - 00:09:40] when i do marc jacobs like whether it's
# [00:09:38 - 00:09:43] a campaign or a show he's just so
# [00:09:40 - 00:09:44] awesome like he just has the best most
# [00:09:43 - 00:09:45] amazing
# [00:09:44 - 00:09:47] ideas
# [00:09:45 - 00:09:49] now that i've kind of done all my
# [00:09:47 - 00:09:52] dewiness i go in with a little bit of
# [00:09:49 - 00:09:53] powder i like this
# [00:09:52 - 00:09:55] mac
# [00:09:53 - 00:09:57] just like pressed powder
# [00:09:55 - 00:09:59] um i use the little mac
# [00:09:57 - 00:10:03] spongy thing and literally all i do is i
# [00:09:59 - 00:10:05] go in right here under my eyes
# [00:10:03 - 00:10:07] around my nose
# [00:10:05 - 00:10:08] chin
# [00:10:07 - 00:10:11] and forehead and i just leave it at that
# [00:10:08 - 00:10:12] like i i'd like to be doing like i said
# [00:10:11 - 00:10:14] so i really
# [00:10:12 - 00:10:17] just kind of work around the places that
# [00:10:14 - 00:10:19] i just put that shine
# [00:10:17 - 00:10:20] i love this estee lauder bronze goddess
# [00:10:19 - 00:10:22] powder
# [00:10:20 - 00:10:26] so i go in over top of everything that i
# [00:10:22 - 00:10:26] just did just to add even
# [00:10:30 - 00:10:36] more growing up my mom had this like
# [00:10:33 - 00:10:38] lucite makeup this clear loose like
# [00:10:36 - 00:10:40] makeup cabinet thing
# [00:10:38 - 00:10:42] sitting on her like vanity and kylie and
# [00:10:40 - 00:10:45] i would go in all the time and like play
# [00:10:42 - 00:10:47] with her stuff and just
# [00:10:45 - 00:10:49] be messy and she only when she wasn't
# [00:10:47 - 00:10:50] home because i feel like she came home
# [00:10:49 - 00:10:53] she'd get really mad at us for like
# [00:10:50 - 00:10:56] messing up all her stuff and my mom
# [00:10:53 - 00:10:57] always said growing up she's like never
# [00:10:56 - 00:10:58] look in this magnifying mirror because
# [00:10:57 - 00:11:00] you're gonna see things that no one sees
# [00:10:58 - 00:11:02] and then you're gonna start picking
# [00:11:00 - 00:11:04] and then she ended up getting rid of
# [00:11:02 - 00:11:05] hers and she was like the best gift you
# [00:11:04 - 00:11:07] can give like an ex-boyfriend who was
# [00:11:05 - 00:11:09] like mean to you as one of these makeup
# [00:11:07 - 00:11:11] mirrors and they'll just go and they'll
# [00:11:09 - 00:11:13] just make themselves break out because
# [00:11:11 - 00:11:16] they just touch it so much
# [00:11:13 - 00:11:18] i am now moving on to a powder blush
# [00:11:16 - 00:11:22] and i really love this little stormy
# [00:11:18 - 00:11:22] collection from kylie cosmetics
# [00:11:24 - 00:11:29] i definitely am so obviously proud of my
# [00:11:27 - 00:11:31] sisters it just it makes so much sense
# [00:11:29 - 00:11:33] for both kim and
# [00:11:31 - 00:11:36] kylie to have these lines like they're
# [00:11:33 - 00:11:38] just it is who they are and literally
# [00:11:36 - 00:11:41] what they've always loved i'm gonna
# [00:11:38 - 00:11:42] brush my brows out now
# [00:11:41 - 00:11:45] i don't
# [00:11:42 - 00:11:46] do too much to my brows to be honest
# [00:11:45 - 00:11:49] i've
# [00:11:46 - 00:11:50] finally gone to a good place with them
# [00:11:49 - 00:11:52] back to the
# [00:11:50 - 00:11:54] estee lauder bronze goddess powder
# [00:11:52 - 00:11:59] bronze powder
# [00:11:54 - 00:11:59] and just put a little that on my eyes
# [00:12:01 - 00:12:06] sometimes this bronze goddess um powder
# [00:12:03 - 00:12:11] isn't a little isn't dark enough for my
# [00:12:06 - 00:12:14] eyelids so i use this serge luton bronze
# [00:12:11 - 00:12:14] powder for my eyes
# [00:12:17 - 00:12:23] i kind of apply in like little circles
# [00:12:20 - 00:12:25] almost around like on my whole eyelid
# [00:12:23 - 00:12:28] like i go for the middle first and then
# [00:12:25 - 00:12:30] i'll come out to the ends a little bit
# [00:12:28 - 00:12:33] right in here but because i'm not using
# [00:12:30 - 00:12:35] like a super dark color it makes my life
# [00:12:33 - 00:12:37] a lot easier so there's not really
# [00:12:35 - 00:12:40] too much messing up i can do you just
# [00:12:37 - 00:12:43] kind of blend it all in
# [00:12:40 - 00:12:43] nicely
# [00:12:52 - 00:12:55] and then
# [00:12:54 - 00:12:56] i will
# [00:12:55 - 00:12:58] take
# [00:12:56 - 00:12:59] kevin
# [00:12:58 - 00:13:03] brown
# [00:12:59 - 00:13:03] hence eye pencil
# [00:13:06 - 00:13:10] so it's going to look a little bit of a
# [00:13:07 - 00:13:13] mess right now and then you'll see how
# [00:13:10 - 00:13:13] magical it is
# [00:13:15 - 00:13:19] all right so
# [00:13:16 - 00:13:21] i did just a little bit smudgy
# [00:13:19 - 00:13:22] on the ends
# [00:13:21 - 00:13:24] put a little bit brown pencils smudge it
# [00:13:22 - 00:13:26] all out so you don't even really it just
# [00:13:24 - 00:13:27] kind of creates that little like darker
# [00:13:26 - 00:13:29] effect right there
# [00:13:27 - 00:13:31] and then now i'm going to take whatever
# [00:13:29 - 00:13:33] is like kind of left on the spongy side
# [00:13:31 - 00:13:37] that i just used this for and just go in
# [00:13:33 - 00:13:37] under just to make this slightly darker
# [00:13:40 - 00:13:46] now i'm going to curl my lashes which is
# [00:13:43 - 00:13:46] never cute
# [00:13:54 - 00:13:57] i don't really have a technique my
# [00:13:56 - 00:13:59] lashes are just really long so i have to
# [00:13:57 - 00:14:01] like get them all in there when anyone
# [00:13:59 - 00:14:03] does my makeup it's the one thing i kind
# [00:14:01 - 00:14:05] of have to do myself
# [00:14:03 - 00:14:07] just because like i feel like i've
# [00:14:05 - 00:14:08] mastered it almost because my lashes
# [00:14:07 - 00:14:10] tend to like i have good lash days and
# [00:14:08 - 00:14:12] bad lash days like these are all my
# [00:14:10 - 00:14:13] natural lashes but sometimes they're
# [00:14:12 - 00:14:15] just
# [00:14:13 - 00:14:17] wacky and they don't want to follow
# [00:14:15 - 00:14:19] instruction so i have to kind of get in
# [00:14:17 - 00:14:20] there and
# [00:14:19 - 00:14:24] tell them what to do
# [00:14:20 - 00:14:24] i'll go in with my armani mascara
# [00:14:34 - 00:14:36] lashes
# [00:14:39 - 00:14:43] one of the best parts
# [00:14:41 - 00:14:46] is my lip i feel like i'm incomplete
# [00:14:43 - 00:14:48] without a lip now and i
# [00:14:46 - 00:14:50] you would have told me
# [00:14:48 - 00:14:52] four years ago that i would have said
# [00:14:50 - 00:14:53] that i would have been like you're crazy
# [00:14:52 - 00:14:55] i would never say that i never used to
# [00:14:53 - 00:14:57] wear lipstick and now i like can't leave
# [00:14:55 - 00:14:59] the house
# [00:14:57 - 00:15:01] well that's a lie i can leave the house
# [00:14:59 - 00:15:03] without it but
# [00:15:01 - 00:15:06] it completes
# [00:15:03 - 00:15:08] a look so i have these two
# [00:15:06 - 00:15:10] different ones this is our secret
# [00:15:08 - 00:15:13] concoction so you're welcome
# [00:15:10 - 00:15:17] this is the kevin flon medium
# [00:15:13 - 00:15:17] and then the giorgio armani
# [00:15:18 - 00:15:20] i love
# [00:15:21 - 00:15:27] a good plumpy lip so i usually
# [00:15:24 - 00:15:27] slightly over line
# [00:15:30 - 00:15:34] i take the lighter one and i kind of go
# [00:15:32 - 00:15:37] in the middle i slightly like
# [00:15:34 - 00:15:39] blend the outer
# [00:15:37 - 00:15:41] line
# [00:15:39 - 00:15:41] into the middle
# [00:15:43 - 00:15:48] super nice not too non natural color
# [00:15:47 - 00:15:51] i take
# [00:15:48 - 00:15:53] my kendall it's called a lip blush it's
# [00:15:51 - 00:15:55] really nice and i honestly just do like
# [00:15:53 - 00:15:58] a little dab right in the middle to just
# [00:15:55 - 00:15:58] even out
# [00:16:00 - 00:16:03] i use the liner as a lipstick pretty
# [00:16:01 - 00:16:04] much like i'll line it then put it in
# [00:16:03 - 00:16:06] the middle and then i'll use like the
# [00:16:04 - 00:16:09] littlest bit of this lip blush just to
# [00:16:06 - 00:16:11] like kind of even everything out
# [00:16:09 - 00:16:13] and it just feels really nice and then i
# [00:16:11 - 00:16:15] go over top of it
# [00:16:13 - 00:16:16] with another
# [00:16:15 - 00:16:20] kendall kylie product i'm telling you we
# [00:16:16 - 00:16:22] made all of our products based on like
# [00:16:20 - 00:16:25] what i actually use so it's like so nice
# [00:16:22 - 00:16:26] and so convenient so i use this it is so
# [00:16:25 - 00:16:28] like
# [00:16:26 - 00:16:30] what
# [00:16:28 - 00:16:30] it's like
# [00:16:31 - 00:16:35] it's so
# [00:16:32 - 00:16:37] thick and good and it lasts all night
# [00:16:35 - 00:16:39] like you could put it on once and it
# [00:16:37 - 00:16:41] lasts all night i have a bad habit of
# [00:16:39 - 00:16:42] like rubbing my lips together all the
# [00:16:41 - 00:16:44] time so
# [00:16:42 - 00:16:47] um i tend to have to reapply but it
# [00:16:44 - 00:16:47] really does
# [00:16:51 - 00:16:54] and i love like a good bratty lip so
# [00:16:53 - 00:16:57] that's why i love like a gloss i think
# [00:16:54 - 00:16:59] also glosses like make your lips
# [00:16:57 - 00:17:01] look a little bigger than they actually
# [00:16:59 - 00:17:03] are so
# [00:17:01 - 00:17:05] this is kind of me and then i'll usually
# [00:17:03 - 00:17:07] like go in last minute because i just am
# [00:17:05 - 00:17:10] a bronze obsessed
# [00:17:07 - 00:17:10] throw a little bit more on
# [00:17:14 - 00:17:20] my kkw beauty
# [00:17:17 - 00:17:23] bronze and shine palette so i use
# [00:17:20 - 00:17:24] this one it's a brand new one i used my
# [00:17:23 - 00:17:26] other one
# [00:17:24 - 00:17:28] i used this guy even on top of like i
# [00:17:26 - 00:17:31] usually go in with the creamy you know
# [00:17:28 - 00:17:34] bronze blush shine and then at the end i
# [00:17:31 - 00:17:38] go in with the powder shine
# [00:17:34 - 00:17:38] powder bronze powder blush
# [00:17:41 - 00:17:46] all right guys so this is my final look
# [00:17:44 - 00:17:49] thank you so much for watching my
# [00:17:46 - 00:17:52] amateur makeup tutorial um i had such a
# [00:17:49 - 00:17:55] nice time thanks for having me vogue
# [00:17:52 - 00:17:55] bye

# %%
if transcript_with_timestamps and transcript_list:

    # Example subtopic
    subtopic = "lip Blush"
    start_time = predict_timestamps(transcript_list, subtopic)
    print(f"Start Time for {subtopic} :", format_time(start_time))
else:
    print("Transcript extraction failed.")
# Out:
# Start Time for lip Blush : 00:16:04

# %%
def generate_youtube_link(video_id, start_time_seconds):
    base_url = f"https://www.youtube.com/watch?v={video_id}"
    time_parameter = f"&t={start_time_seconds}s"
    return base_url + time_parameter

# Example usage:
video_id = 'PYS3UZFPJWI'
start_time_seconds = 964  # 00:16:04 in seconds
youtube_link = generate_youtube_link(video_id, start_time_seconds)
print("YouTube Link:", youtube_link)
# Out:
# YouTube Link: https://www.youtube.com/watch?v=PYS3UZFPJWI&t=964s

# %%
def generate_youtube_link(video_id, start_time_seconds):
    base_url = f"https://www.youtube.com/watch?v={video_id}"
    time_parameter = f"&t={start_time_seconds}s"
    return base_url + time_parameter

# %%
if transcript_with_timestamps and transcript_list:
    # Example subtopic
    subtopic = "lip Blush"
    start_time = predict_timestamps(transcript_list, subtopic)
    print(f"Start Time for {subtopic} :", format_time(start_time))

    # Generate YouTube link
    video_id = 'PYS3UZFPJWI'  # Replace with your video ID
    youtube_link = generate_youtube_link(video_id, start_time)
    print("YouTube Link:", youtube_link)
else:
    print("Transcript extraction failed.")
# Out:
# Start Time for lip Blush : 00:16:04
# YouTube Link: https://www.youtube.com/watch?v=PYS3UZFPJWI&t=964.959s
